# %% [markdown]
# # Прогнозирование отношения доллара к евро

# %% [markdown]
# ## Подключение библиотек

# %%
import os

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(
    rc = {
        'figure.figsize': (16, 9),
        'figure.dpi': 80,
        'axes.grid': True,
        'axes.grid.axis': 'x',
        'axes.grid.which': 'both',
        'grid.alpha': .4,
        'xtick.minor.visible': True,
        },
    palette = 'colorblind',
    style = 'ticks'
)
from copy import deepcopy
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm

# %% [markdown]
# ## 1 Датасет

# %% [markdown]
# ### 1.1 Анализ и преобразование данных

# %%
os.listdir('data')
# Out:
# ['ECB_FX_USD-quote.csv', 'euro-dollar-exchange-rate-historical-chart.csv']

# %% [markdown]
# Датасет взят отсюда: https://data.humdata.org/dataset/ecb-fx-rates?force_layout=desktop

# %%
df = pd.read_csv('data/ECB_FX_USD-quote.csv')
df.head()
# Out:
#          Date         EUR                   JPY                 BGN  \
# 0       #date  #value+eur            #value+jpy          #value+bgn
# 1  2021-10-11      1.1574   0.00885539403213466  0.5917783004397178
# 2  2021-10-08      1.1569   0.00894602536343953  0.5915226505777688
# 3  2021-10-07      1.1562   0.00897810218978102    0.59116474077104
# 4  2021-10-06      1.1542  0.008980703392468098  0.5901421413232436
#
#                     CZK                  DKK                 GBP  \
# 0            #value+czk           #value+dkk          #value+gbp
# 1   0.04556872317807788  0.15553942912433477  1.3636042319564552
# 2  0.045486356845167886  0.15547014634539663  1.3628224761456003
# 3  0.045492819201259097  0.15540531458756165  1.3598673300165836
# 4    0.0454141255164273  0.15513857899405897   1.358361774744027
#
#                      HUF                  PLN                  RON  ...  \
# 0             #value+huf           #value+pln           #value+ron  ...
# 1  0.0032087607429997227  0.25208546599002457  0.23385125169215848  ...
# 2  0.0032119159332574475  0.25050885626434544  0.23379746579633412  ...
# 3   0.003228166182711637   0.2543446698050948  0.23369378473976754  ...
# 4   0.003211195503992432   0.2513228089275993   0.2333697278498928  ...
#
#                    ILS                   INR                    KRW  \
# 0           #value+ils            #value+inr             #value+krw
# 1   0.3098131591626961  0.013252570591064189  0.0008366162364557657
# 2  0.30954674372558466  0.013336099919884265  0.0008372412794905197
# 3   0.3095333708135892  0.013380705490232384  0.0008403410205906081
# 4   0.3081811385239773  0.013352923482727503  0.0008364313614656027
#
#                    MXN                  MYR                 NZD  \
# 0           #value+mxn           #value+myr          #value+nzd
# 1  0.04821475436469751  0.23980606663351567   0.693884892086331
# 2  0.04854906733250803  0.23935036722871628   0.693335730552559
# 3  0.04877822403726079  0.23903245813520776  0.6933317342288318
# 4  0.04816371155186299  0.23897964676895045  0.6899808703969392
#
#                     PHP                 SGD                   THB  \
# 0            #value+php          #value+sgd            #value+thb
# 1  0.019642251035231824  0.7388445579316949  0.029529276693455796
# 2  0.019799760397056308  0.7377718257764173   0.02954214652332678
# 3  0.019829182959456678   0.736573867618016   0.02960743642928478
# 4   0.01962791646826746  0.7345977596741344   0.02950710706616218
#
#                    ZAR
# 0           #value+zar
# 1  0.06685999491646832
# 2  0.06716049669393181
# 3  0.06719202203703058
# 4  0.06612015284055431
#
# [5 rows x 34 columns]

# %% [markdown]
# Избавимся от первой строки с технической информацией, а также и от лишних столбцов.

# %%
df = df.drop(labels=0)
df.reset_index(inplace=True)
df = df.loc[:,["Date","EUR"]]
df.head()
# Out:
#          Date     EUR
# 0  2021-10-11  1.1574
# 1  2021-10-08  1.1569
# 2  2021-10-07  1.1562
# 3  2021-10-06  1.1542
# 4  2021-10-05  1.1602

# %% [markdown]
# Выведем информацию о данных.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5831 entries, 0 to 5830
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    5831 non-null   object
#  1   EUR     5831 non-null   object
# dtypes: object(2)
# memory usage: 91.2+ KB

# %% [markdown]
# Преобразуем значения столбца Date в тип datetime, а столбец EUR во float.

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['EUR'] = df['EUR'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5831 entries, 0 to 5830
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    5831 non-null   datetime64[ns]
#  1   EUR     5831 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 91.2 KB

# %%
df.head()
# Out:
#         Date     EUR
# 0 2021-10-11  1.1574
# 1 2021-10-08  1.1569
# 2 2021-10-07  1.1562
# 3 2021-10-06  1.1542
# 4 2021-10-05  1.1602

# %% [markdown]
# Для удобстава инвертируем таблицу.

# %%
df = df.iloc[::-1]
df = df.reset_index(drop=True)
df.head()
# Out:
#         Date     EUR
# 0 1999-01-04  1.1789
# 1 1999-01-05  1.1790
# 2 1999-01-06  1.1743
# 3 1999-01-07  1.1632
# 4 1999-01-08  1.1659

# %%
sns.lineplot(x=df['Date'],y=df['EUR'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='EUR'>

# %% [markdown]
# ### 1.2 Разбивка датасета на обучающую и тренировочную выборки

# %% [markdown]
# Перед разбивкой датасета на основании столбца получим более удобную величину чем даты - столбец с номером даты. Так как датасет ежедневные наблюдения, то проблем при обучении возникнуть не должно.

# %%
# df['time'] = np.arange(len(df['Date']))
# df.head()

# %%
# df['lag_1'] = df['EUR'].shift(1)
# df.head()

# %% [markdown]
# Произведём стандартизацию данных.

# %%
df.loc[:,'EUR'] = (df['EUR'] - df['EUR'].mean()) / df['EUR'].std()

# %% [markdown]
# Разбивка датасета на тренировочную и тестовую выборки

# %%
border_line = int(len(df)*0.8)

data_train, data_test = df.iloc[:border_line], df.iloc[border_line:]
data_test.index = np.arange(len(data_test))

# %% [markdown]
# ## 2 Выбор значения глубины прогноза

# %%
TAU_LIST = [2,7,14,30,60]

# %% [markdown]
# ## 3 Выбор структуры ИНС

# %%
# class NN:
#     def __init__(self,nn_shape):
#         self.nn_shape = nn_shape
#         self.layers = []
#         self.weights = []
#         self.bias = []
#         self.dw = []
#         self.db = []
#         self.vw = []
#         self.vb = []
#         self.RHO = 0.90
        
#         for layer_n in range(len(nn_shape)):
#             self.layers.append(np.zeros(nn_shape[layer_n],dtype=np.float64))
#             if layer_n!=0:
#                 self.weights.append(np.random.normal(size=(nn_shape[layer_n-1],nn_shape[layer_n])))
#                 self.bias.append(np.random.normal(size=nn_shape[layer_n]))
                
#                 # массивы для значений градиентов
#                 self.dw.append(np.zeros((nn_shape[layer_n-1],nn_shape[layer_n]),dtype = np.float64)) 
#                 self.db.append(np.zeros(nn_shape[layer_n],dtype = np.float64))

#         self.vw = deepcopy(self.weights)
#         self.vb = deepcopy(self.bias)
                    
#     def sigmoid(self,x):
#         return 1/(1 + np.exp(-x))
    
#     def forward(self,x):
#         for i in range(len(self.layers)):
#             if i== 0:
#                 self.layers[i]=x
#             else:
#                 self.layers[i]=self.sigmoid(x+self.bias[i-1])
#             if i!= len(self.layers)-1:
#                 x = np.dot(self.weights[i].T,self.layers[i])
# #                 x = self.weights[i].T@self.layers[i]
                
#         return self.sigmoid(x + self.bias[-1])
    
#     def back_propagation(self,y,lr=10e-4*5,weight_decay=0.0005):
#         # вычисляем градиенты для weights
#         for L in range(1,len(self.layers)):
#             for i in range(len(self.layers[-L])):
#                 for j in range(len(self.layers[-L-1])):
#                     if L == 1:
#                         # dw
#                         try:
#                             dE_w = (self.layers[-L][i]-y[i])
#                         except IndexError:
#                             dE_w = (self.layers[-L][i]-y)
#                         da_w = self.layers[-L][i]*(1-self.layers[-L][i])                                              
#                         dz_w = self.layers[-L-1][j]
                        

#                     else:
#                         # dw
#                         dE_w = np.dot(self.dw[-L+1][i,:],self.weights[-L+1][i,:])
#                         da_w = self.layers[-L][i]*(1-self.layers[-L][i])
#                         try:
#                             dz_w = self.layers[-L-1][j]
#                         except KeyError:
#                             dz_w = self.layers[-L-1]
#                     self.dw[-L][j,i] = dE_w*da_w*dz_w         
        
#          # вычисляем градиенты для bias  
#         for L in range(1,len(self.db)+1):
#             for i in range(len(self.db[-L])):
#                 if L!=1:
#                     dE_b = np.dot(self.weights[-L+1][i],self.db[-L+1])
#                     da_b = self.layers[-L][i]*(1-self.layers[-L][i])
#                     dz_b = 1
                        
#                 else:
# #                     dE_b = self.layers[-L][i]*(self.layers[-L+1][i]-y[i])
#                     try:
#                         dE_b = (self.layers[-L+1][i]-y[i])
#                     except IndexError:
#                         dE_b = (self.layers[-L+1][i]-y)
#                     da_b = self.layers[-L+1][i]*(1-self.layers[-L+1][i])
#                     dz_b = 1
                    
#                 self.db[-L][i] = dE_b*da_b*dz_b
                
#         # применяем градиенты к weights        
#         for L in range(len(self.dw)):
#             self.vw[L] = self.RHO * self.vw[L] + self.dw[L] + weight_decay * self.weights[L]
#             self.weights[L]-=lr * self.vw[L]
        
#         # применяем градиенты к bias
#         for L in range(len(self.db)):
# #             self.vb[L] = self.RHO * self.vb[L] + self.db[L] + weight_decay * self.bias[L]
# #             self.bias[L] -= lr * self.vb[L]
#             self.bias[L] -= lr * self.db[L]
    
#     def __repr__(self):
#         return f'NN({self.nn_shape})'

# %%
class NN:
    def __init__(self,nn_shape):
        self.nn_shape = nn_shape
        self.layers = []
        self.weights = []
        self.bias = []
        self.dw = []
        self.db = []
        self.vw = []
        self.vb = []
        self.RHO = 0.90
        
        for layer_n in range(len(nn_shape)):
            self.layers.append(np.zeros(nn_shape[layer_n],dtype=np.float64))
            if layer_n!=0:
                self.weights.append(np.random.normal(size=(nn_shape[layer_n-1],nn_shape[layer_n])))
                self.bias.append(np.random.normal(size=nn_shape[layer_n]))
                
                # массивы для значений градиентов
                self.dw.append(np.zeros((nn_shape[layer_n-1],nn_shape[layer_n]),dtype = np.float64)) 
                self.db.append(np.zeros(nn_shape[layer_n],dtype = np.float64))

        self.vw = deepcopy(self.weights)
        self.vb = deepcopy(self.bias)
                    
    def tanh(self,x):
        return 2 / (1 + np.exp(-2 * x)) - 1
    
    def forward(self,x):
        for i in range(len(self.layers)):
            if i== 0:
                self.layers[i]=x
            else:
                self.layers[i]=self.tanh(x+self.bias[i-1])
            if i!= len(self.layers)-1:
                x = np.dot(self.weights[i].T,self.layers[i])
#                 x = self.weights[i].T@self.layers[i]
                
        return self.tanh(x + self.bias[-1])
    
    def back_propagation(self,y,lr=10e-4*5,weight_decay=0.0005):
        # вычисляем градиенты для weights
        for L in range(1,len(self.layers)):
            for i in range(len(self.layers[-L])):
                for j in range(len(self.layers[-L-1])):
                    if L == 1:
                        # dw
                        try:
                            dE_w = (self.layers[-L][i]-y[i])
                        except IndexError:
                            dE_w = (self.layers[-L][i]-y)
                        da_w = 1 - self.layers[-L][i] * self.layers[-L][i]                                             
                        dz_w = self.layers[-L-1][j]
                        

                    else:
                        # dw
                        dE_w = np.dot(self.dw[-L+1][i,:],self.weights[-L+1][i,:])
                        da_w = 1 - self.layers[-L][i] * self.layers[-L][i]
                        try:
                            dz_w = self.layers[-L-1][j]
                        except KeyError:
                            dz_w = self.layers[-L-1]
                    self.dw[-L][j,i] = dE_w*da_w*dz_w         
        
         # вычисляем градиенты для bias  
        for L in range(1,len(self.db)+1):
            for i in range(len(self.db[-L])):
                if L!=1:
                    dE_b = np.dot(self.weights[-L+1][i],self.db[-L+1])
                    da_b = 1 - self.layers[-L][i] * self.layers[-L][i]
                    dz_b = 1
                        
                else:
#                     dE_b = self.layers[-L][i]*(self.layers[-L+1][i]-y[i])
                    try:
                        dE_b = (self.layers[-L+1][i]-y[i])
                    except IndexError:
                        dE_b = (self.layers[-L+1][i]-y)
                    da_b = 1 - self.layers[-L+1][i] * self.layers[-L+1][i]
                    dz_b = 1
                    
                self.db[-L][i] = dE_b*da_b*dz_b
                
        # применяем градиенты к weights        
        for L in range(len(self.dw)):
            self.vw[L] = self.RHO * self.vw[L] + self.dw[L] + weight_decay * self.weights[L]
            self.weights[L]-=lr * self.vw[L]
        
        # применяем градиенты к bias
        for L in range(len(self.db)):
#             self.vb[L] = self.RHO * self.vb[L] + self.db[L] + weight_decay * self.bias[L]
#             self.bias[L] -= lr * self.vb[L]
            self.bias[L] -= lr * self.db[L]
    
    def __repr__(self):
        return f'NN({self.nn_shape})'

# %% [markdown]
# ## Обучение

# %%
def train(model,X_train,epochs=1,tau = 2,X_val=None):
    train_loss_history = []
    for i in range(epochs):
        running_loss = 0
        for i in range(len(X_train)//tau - 1):
            X_pred = net.forward(X_train[i*tau:i*tau+tau])
            running_loss += np.sum(np.square(X_pred-X_train[i*tau+tau]))/2
            net.back_propagation(X_train[i*tau+tau])
        epoch_loss = running_loss/len(X_train)
        train_loss_history.append(epoch_loss)
        if len(train_loss_history) > 5:
            if np.isclose(train_loss_history[-1],train_loss_history[-4], rtol=1e-02, atol=1e-04):
                break
    return train_loss_history

# %% [markdown]
# Цикл обучения модели

# %%
tau_current_experiment = 2
net = NN((tau_current_experiment,6,6,1))

train_loss = train(net,data_train['EUR'].to_numpy(),epochs=50)

# %% [markdown]
# Построим получившийся график

# %%
plt.plot(train_loss)
plt.title("Train Loss to Epoch")
plt.show()

# %% [markdown]
# ## Тест предсказаний

# %%
eur_pred_list = []
date_list = []
mean_square_error = 0
for ind in range(len(data_test)-tau_current_experiment):
    eur_pred = float(net.forward(data_test.loc[ind:ind+tau_current_experiment-1,'EUR'].to_numpy()))
    mean_square_error += (data_test.loc[ind+tau_current_experiment-1,'EUR'])**2
    date = data_test.loc[ind+tau_current_experiment-1,'Date']
    eur_pred_list.append(eur_pred)
    date_list.append(date)
    
mean_square_error = mean_square_error / len(eur_pred_list)
print('Среднеквадратичная ошибка:',mean_square_error)
# Out:
# Среднеквадратичная ошибка: 0.14822554553595377

# %%
sns.lineplot(x=date_list, y=eur_pred_list, label='real data')
sns.lineplot(x=data_test.loc[:,'Date'], y=data_test.loc[:,'EUR'], label=net)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='EUR'>

# %% [markdown]
# ## Исследование влияния гиперпараметров на точность прогноза

# %%
def forecast_timeseries(model, data_test, tau):
    """Функция предсказания временных рядов"""
    eur_pred_list = []
    for ind, _ in enumerate(data_test[tau:], tau):
        eur_pred = float(model.forward(data_test[ind-tau:ind]))
        eur_pred_list.append(eur_pred)
        
    return eur_pred_list

def get_mse(pred_list, real_list):
    """Среднеквадратичное отклонение временного ряда"""
    return np.sum((pred_list - real_list)**2)/ len(pred_list)

# %%
def test_model(model,data_test,tau):
    """Функция для тестирования временного ряда"""
    # Получение ряда предсказаний
    eur_pred_list = forecast_timeseries(model,data_test,tau)
    
    # Получение среднеквадратичной ошибки
    mean_square_error = get_mse(eur_pred_list, data_test[tau:])

    return mean_square_error

test_model(net,data_test['EUR'].to_numpy(),2)
# Out:
# 0.06216714868053764

# %%
ITERATIONS = 10
EPOCHS = 100

# %% [markdown]
# ### Персептрон без скрытых слоёв

# %%
# Строим график с эталонными метками
sns.lineplot(x=data_test.loc[:,'Date'], y=data_test.loc[:,'EUR'], label='real data')
for tau_current_experiment in tqdm(TAU_LIST):
    mse = np.array([])
    for iteration in range(ITERATIONS):
        net = NN((tau_current_experiment,1))
        train_loss = train(net,data_train['EUR'].to_numpy(),epochs=EPOCHS,tau=tau_current_experiment)
        mse_current = test_model(net,data_test['EUR'].to_numpy(),tau_current_experiment)
        mse = np.hstack((mse,mse_current))
    eur_pred_list = forecast_timeseries(net, data_test['EUR'].to_numpy(), tau_current_experiment)
    sns.lineplot(x=data_test.loc[tau_current_experiment:,'Date'], y=eur_pred_list, label=net)    
    print(tau_current_experiment)
    print(net)
    print('mean:',mse.mean())
    print('std:',mse.std())
    print('mse min:',np.min(mse))
# Out:
#  20%|████████████████▊                                                                   | 1/5 [01:12<04:51, 72.91s/it]
# 2
# NN((2, 1))
# mean: 0.2827388107049803
# std: 0.19553587045390006
# mse min: 0.006725787184890573
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:24<01:50, 36.79s/it]
# 7
# NN((7, 1))
# mean: 0.18898736797559695
# std: 0.19140737077342354
# mse min: 0.007462840439571356
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [01:31<00:46, 23.16s/it]
# 14
# NN((14, 1))
# mean: 0.22757872159211665
# std: 0.2044752434290526
# mse min: 0.01427953720677437
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [01:35<00:15, 15.61s/it]
# 30
# NN((30, 1))
# mean: 0.2934298830435565
# std: 0.1547490614361239
# mse min: 0.06189859676027089
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [01:38<00:00, 19.78s/it]
# 60
# NN((60, 1))
# mean: 0.28436202941707445
# std: 0.1523078601713346
# mse min: 0.06395425108840293

# %% [markdown]
# ### Персептрон с одним скрытым слоем

# %%
sns.lineplot(x=data_test.loc[:,'Date'], y=data_test.loc[:,'EUR'], label='real data')
for tau_current_experiment in tqdm(TAU_LIST):
    mse = np.array([])
    for iteration in range(ITERATIONS):
        net = NN((tau_current_experiment,10,1))
        train_loss = train(net,data_train['EUR'].to_numpy(),epochs=EPOCHS,tau=tau_current_experiment)
        mse_current = test_model(net,data_test['EUR'].to_numpy(),tau_current_experiment)
        mse = np.hstack((mse,mse_current))
    eur_pred_list = forecast_timeseries(net, data_test['EUR'].to_numpy(), tau_current_experiment)
    sns.lineplot(x=data_test.loc[tau_current_experiment:,'Date'], y=eur_pred_list, label=net)    
    print(tau_current_experiment)
    print(net)
    print('mean:',mse.mean())
    print('std:',mse.std())
    print('mse min:',np.min(mse))
# Out:
#  20%|████████████████▊                                                                   | 1/5 [01:29<05:57, 89.32s/it]
# 2
# NN((2, 10, 1))
# mean: 0.0738601984046908
# std: 0.10932788273019127
# mse min: 0.004454638017730861
#  40%|█████████████████████████████████▌                                                  | 2/5 [02:38<03:51, 77.22s/it]
# 7
# NN((7, 10, 1))
# mean: 0.059754684105228405
# std: 0.11050333544385761
# mse min: 0.005287692298842155
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [03:36<02:16, 68.49s/it]
# 14
# NN((14, 10, 1))
# mean: 0.17903420138387655
# std: 0.12850778814148153
# mse min: 0.010204179901923675
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [04:10<00:55, 55.03s/it]
# 30
# NN((30, 10, 1))
# mean: 0.30673897650062243
# std: 0.1227472311352341
# mse min: 0.10818018178280561
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [04:37<00:00, 55.53s/it]
# 60
# NN((60, 10, 1))
# mean: 0.4746258986591994
# std: 0.10806142001556229
# mse min: 0.26251598701823564

# %% [markdown]
# ### Персептрон с двумя скрытыми слоями

# %%
sns.lineplot(x=data_test.loc[:,'Date'], y=data_test.loc[:,'EUR'], label='real data')
for tau_current_experiment in tqdm(TAU_LIST):
    mse = np.array([])
    for iteration in range(ITERATIONS):
        net = NN((tau_current_experiment,10,10,1))
        train_loss = train(net,data_train['EUR'].to_numpy(),epochs=EPOCHS,tau=tau_current_experiment)
        mse_current = test_model(net,data_test['EUR'].to_numpy(),tau_current_experiment)
        mse = np.hstack((mse,mse_current))
    eur_pred_list = forecast_timeseries(net, data_test['EUR'].to_numpy(), tau_current_experiment)
    sns.lineplot(x=data_test.loc[tau_current_experiment:,'Date'], y=eur_pred_list, label=net)    
    print(tau_current_experiment)
    print(net)
    print('mean:',mse.mean())
    print('std:',mse.std())
    print('mse min:',np.min(mse))
# Out:
#  20%|████████████████▌                                                                  | 1/5 [03:34<14:19, 215.00s/it]
# 2
# NN((2, 10, 10, 1))
# mean: 0.10590878008725416
# std: 0.1728659361605114
# mse min: 0.0037449957539298483
#  40%|█████████████████████████████████▏                                                 | 2/5 [05:58<08:38, 172.78s/it]
# 7
# NN((7, 10, 10, 1))
# mean: 0.0823007214169045
# std: 0.0689439859293131
# mse min: 0.005375163729057525
#  60%|█████████████████████████████████████████████████▊                                 | 3/5 [07:57<04:56, 148.24s/it]
# 14
# NN((14, 10, 10, 1))
# mean: 0.21728891554298285
# std: 0.1790061441384116
# mse min: 0.026127677927299458
#  80%|██████████████████████████████████████████████████████████████████▍                | 4/5 [09:03<01:55, 115.89s/it]
# 30
# NN((30, 10, 10, 1))
# mean: 0.4060519572321673
# std: 0.09742106955543998
# mse min: 0.1829699603651994
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [10:35<00:00, 127.07s/it]
# 60
# NN((60, 10, 10, 1))
# mean: 0.4756868459321657
# std: 0.08422633206608031
# mse min: 0.3098270961361489

# %% [markdown]
# ## Ряд разностей

# %%
data_sub = (df['EUR'] - df['EUR'].shift(1)).to_numpy()
data_sub[0] = 0

# %%
border_line = int(len(df)*0.8)

data_sub_train, data_sub_test = data_sub[:border_line], data_sub[border_line:]

# %% [markdown]
# ### Персептрон без скрытых слоёв

# %%
sns.lineplot(x=data_test.loc[:,'Date'], y=data_sub_test, label='real data')
for tau_current_experiment in tqdm(TAU_LIST):
    mse = np.array([])
    for iteration in range(ITERATIONS):
        net = NN((tau_current_experiment,1))
        train_loss = train(net,data_sub_train,epochs=EPOCHS,tau=tau_current_experiment)
        mse_current = test_model(net,data_sub_test,tau_current_experiment)
        mse = np.hstack((mse,mse_current))
    eur_pred_list = forecast_timeseries(net, data_sub_test, tau_current_experiment)
    sns.lineplot(x=data_test.loc[tau_current_experiment:,'Date'], y=eur_pred_list, label=net)    
    print(tau_current_experiment)
    print(net)
    print('mean:',mse.mean())
    print('std:',mse.std())
    print('mse min:',np.min(mse))
# Out:
#  20%|████████████████▊                                                                   | 1/5 [01:00<04:03, 60.81s/it]
# 2
# NN((2, 1))
# mean: 0.5080970190923189
# std: 0.34820554128821846
# mse min: 0.01783691523609249
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:26<01:59, 39.91s/it]
# 7
# NN((7, 1))
# mean: 0.3060981376739201
# std: 0.26482160075205746
# mse min: 0.010088219933387299
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [01:42<00:58, 29.39s/it]
# 14
# NN((14, 1))
# mean: 0.3531428387265522
# std: 0.31788208729622114
# mse min: 0.0056924172462736004
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [01:55<00:22, 22.67s/it]
# 30
# NN((30, 1))
# mean: 0.4075970424278057
# std: 0.26812446266861134
# mse min: 0.07575918823743372
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [02:05<00:00, 25.10s/it]
# 60
# NN((60, 1))
# mean: 0.4928697984544389
# std: 0.2886755143174431
# mse min: 0.038864793408337726

# %% [markdown]
# ### Персептрон с одним скрытым слоем

# %%
sns.lineplot(x=data_test.loc[:,'Date'], y=data_sub_test, label='real data')
for tau_current_experiment in tqdm(TAU_LIST):
    mse = np.array([])
    for iteration in range(ITERATIONS):
        net = NN((tau_current_experiment, 10, 1))
        train_loss = train(net,data_sub_train,epochs=EPOCHS,tau=tau_current_experiment)
        mse_current = test_model(net,data_sub_test,tau_current_experiment)
        mse = np.hstack((mse,mse_current))
    eur_pred_list = forecast_timeseries(net, data_sub_test, tau_current_experiment)
    sns.lineplot(x=data_test.loc[tau_current_experiment:,'Date'], y=eur_pred_list, label=net)    
    print(tau_current_experiment)
    print(net)
    print('mean:',mse.mean())
    print('std:',mse.std())
    print('mse min:',np.min(mse))
# Out:
#  20%|████████████████▌                                                                  | 1/5 [04:16<17:06, 256.63s/it]
# 2
# NN((2, 10, 1))
# mean: 0.0011704538111568558
# std: 0.00021970124776504474
# mse min: 0.000928010365335734
#  40%|█████████████████████████████████▏                                                 | 2/5 [07:09<10:22, 207.38s/it]
# 7
# NN((7, 10, 1))
# mean: 0.0013300900784782759
# std: 0.00016021859255501027
# mse min: 0.0011222344772412669
#  60%|█████████████████████████████████████████████████▊                                 | 3/5 [09:53<06:15, 187.64s/it]
# 14
# NN((14, 10, 1))
# mean: 0.09826255012428006
# std: 0.2887783923407071
# mse min: 0.0013785938504590994
#  80%|██████████████████████████████████████████████████████████████████▍                | 4/5 [13:01<03:07, 187.66s/it]
# 30
# NN((30, 10, 1))
# mean: 0.0037262983720454433
# std: 0.0014343494337385023
# mse min: 0.0017266066366919493
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [16:12<00:00, 194.58s/it]
# 60
# NN((60, 10, 1))
# mean: 0.007099036069443443
# std: 0.003157014242864928
# mse min: 0.0038842728352146204

# %% [markdown]
# ### Персептрон с двумя скрытыми слоями

# %%
sns.lineplot(x=data_test.loc[:,'Date'], y=data_sub_test, label='real data')
for tau_current_experiment in tqdm(TAU_LIST):
    mse = np.array([])
    for iteration in range(ITERATIONS):
        net = NN((tau_current_experiment, 10, 10, 1))
        train_loss = train(net,data_sub_train,epochs=EPOCHS,tau=tau_current_experiment)
        mse_current = test_model(net,data_sub_test,tau_current_experiment)
        mse = np.hstack((mse,mse_current))
    eur_pred_list = forecast_timeseries(net, data_sub_test, tau_current_experiment)
    sns.lineplot(x=data_test.loc[tau_current_experiment:,'Date'], y=eur_pred_list, label=net)    
    print(tau_current_experiment)
    print(net)
    print('mean:',mse.mean())
    print('std:',mse.std())
    print('mse min:',np.min(mse))
# Out:
#  20%|████████████████▌                                                                  | 1/5 [11:43<46:55, 703.83s/it]
# 2
# NN((2, 10, 10, 1))
# mean: 0.0015038376106540912
# std: 0.0002941444419599766
# mse min: 0.0011261875091504404
#  40%|█████████████████████████████████▏                                                 | 2/5 [17:15<24:14, 484.92s/it]
# 7
# NN((7, 10, 10, 1))
# mean: 0.10162288197645293
# std: 0.29951024880257276
# mse min: 0.0015354868046892497
#  60%|█████████████████████████████████████████████████▊                                 | 3/5 [20:42<11:55, 357.86s/it]
# 14
# NN((14, 10, 10, 1))
# mean: 0.1014844789290825
# std: 0.3000164614796166
# mse min: 0.0010773777966862266
#  80%|██████████████████████████████████████████████████████████████████▍                | 4/5 [23:45<04:49, 289.10s/it]
# 30
# NN((30, 10, 10, 1))
# mean: 0.20648580635074604
# std: 0.3976288572279088
# mse min: 0.002096233963964187
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [25:56<00:00, 311.30s/it]
# 60
# NN((60, 10, 10, 1))
# mean: 0.3162044754452545
# std: 0.4463710681863323
# mse min: 0.005852437822645613
